# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read the data from the file
file_path = "results/bubble_sort.txt"
data = pd.read_csv(file_path, delim_whitespace=True, names=['Size', 'Sorting Time', 'Unity'])
data = data.sort_values(by='Size').reset_index()
data
# Out:
#     index   Size  Sorting Time Unity
# 0      14   1000      0.005443   sec
# 1      25   2000      0.021902   sec
# 2       8   3000      0.048330   sec
# 3      16   4000      0.088225   sec
# 4       3   5000      0.136362   sec
# 5      22   6000      0.196004   sec
# 6       4   7000      0.268043   sec
# 7      15   8000      0.347953   sec
# 8       2   9000      0.438590   sec
# 9       0  10000      0.555771   sec
# 10     18  11000      0.653415   sec
# 11      5  12000      0.779312   sec
# 12     21  13000      0.913750   sec
# 13     12  14000      1.065580   sec
# 14     26  15000      1.229500   sec
# 15     10  16000      1.384190   sec
# 16     23  17000      1.562310   sec
# 17     13  18000      1.757200   sec
# 18     27  19000      1.984830   sec
# 19      9  20000      2.157710   sec
# 20     24  21000      2.392930   sec
# 21     11  22000      2.615560   sec
# 22     28  23000      2.894170   sec
# 23      7  24000      3.122150   sec
# ...

# %%
# Read the data from the file
file_path = "results/validation.txt"
data = pd.read_csv(file_path, delim_whitespace=True, names=['Size', 'Sorting Time', 'Unity'])
data = data.sort_values(by='Size').reset_index()
data
# Out:
#     index   Size  Sorting Time Unity
# 0      14   1000      0.000012   sec
# 1      25   2000      0.000024   sec
# 2       8   3000      0.000039   sec
# 3      16   4000      0.000049   sec
# 4       3   5000      0.000067   sec
# 5      22   6000      0.000078   sec
# 6       4   7000      0.000085   sec
# 7      15   8000      0.000106   sec
# 8       2   9000      0.000119   sec
# 9       0  10000      0.000302   sec
# 10     18  11000      0.000121   sec
# 11      5  12000      0.000146   sec
# 12     21  13000      0.000145   sec
# 13     12  14000      0.000157   sec
# 14     26  15000      0.000166   sec
# 15     10  16000      0.000176   sec
# 16     23  17000      0.000215   sec
# 17     13  18000      0.000219   sec
# 18     27  19000      0.000209   sec
# 19      9  20000      0.000265   sec
# 20     24  21000      0.000264   sec
# 21     11  22000      0.000279   sec
# 22     28  23000      0.000290   sec
# 23      7  24000      0.000287   sec
# ...

# %%
# Create a scatter plot using seaborn
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

sns.lineplot(data=data, x='Size', y='Sorting Time')

# Set labels and title
plt.xlabel('Graph Size')
plt.ylabel('Validation Time (sec)')
plt.title('Validation Time vs. Graph Size')



# Save the plot
plt.savefig('validation_time_vs_graph_size.png', bbox_inches='tight')
# Show the plot
plt.show()

# %%
# Read data for each sorting algorithm
sorting_algorithms = ['bubble_sort', 'selection_sort', 'insertion_sort', 'quick_sort', 'merge_sort', 'heap_sort', 'count_sort']

# Create an empty DataFrame to store all data
all_data = pd.DataFrame()

# Read and concatenate data for each sorting algorithm
for algorithm in sorting_algorithms:
    file_path = f"results/{algorithm}.txt"
    data = pd.read_csv(file_path, delim_whitespace=True, names=['Size', 'Sorting Time', 'Unity'])
    data['Algorithm'] = algorithm
    all_data = pd.concat([all_data, data])

# Create a scatter plot using seaborn
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=all_data, x='Size', y='Sorting Time', hue='Algorithm', style='Algorithm', markers=True, legend='full')

# Set labels and title
plt.xlabel('Graph Size')
plt.ylabel('Sorting Time (sec)')
plt.title('Sorting Time vs. Graph Size')

# Show the legend
plt.legend(title='Algorithm', loc='upper left', bbox_to_anchor=(0, 1), borderaxespad=0.)


# Save the plot
plt.savefig('sorting_time_vs_graph_size.png', bbox_inches='tight')
# Show the plot
plt.show()

# %%
time = time.to_list()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 time = time.to_list()
#
# AttributeError: 'list' object has no attribute 'to_list'

# %%
derivadas = []
for i in range(1, len(time)-1):
    derivadas.append((time[i] - time[i-1])/100)

# %%
plt.plot(derivadas)
