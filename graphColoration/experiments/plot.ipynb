# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read the data from the file
file_path = "results/heap_sort.txt"
data = pd.read_csv(file_path, delim_whitespace=True, names=['Size', 'Sorting Time', 'Unity'])
data.sort_values(by='Size').reset_index()
# Out:
#     index     Size  Sorting Time Unity
# 0       0    10000      0.002088   sec
# 1      32    20000      0.002106   sec
# 2      39    30000      0.002187   sec
# 3      99    40000      0.002260   sec
# 4      83    50000      0.002240   sec
# ..    ...      ...           ...   ...
# 95     90   960000      0.002351   sec
# 96     84   970000      0.002461   sec
# 97     44   980000      0.002336   sec
# 98     36   990000      0.002364   sec
# 99     58  1000000      0.002453   sec
#
# [100 rows x 4 columns]

# %%
# Create a scatter plot using seaborn
plt.plot(data['Size'], data['Sorting Time'])

# Set labels and title
plt.xlabel('Number')
plt.ylabel('Sorting Time (sec)')
plt.title('Sorting Time vs. Number')

# Show the plot
plt.show()
